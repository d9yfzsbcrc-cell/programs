# %% [markdown]
# # Ejemplos de sympy

# %%
from sympy import *
x, y, z = symbols('x y z')
init_printing()

# %%
Integral(sqrt(1/x), x)
# Out:
# ⌠
# ⎮     ___
# ⎮    ╱ 1
# ⎮   ╱  ─  dx
# ⎮ ╲╱   x
# ⌡
