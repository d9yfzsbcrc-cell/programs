# %% [markdown]
# Ejemplo PID

# %%
# Import the packages needed for the examples included in this notebook
import numpy as np
import matplotlib.pyplot as plt
import control as ct

# %% [markdown]
# Definición del sistema

# %%
T = 0.1
k = 0.149
num = [1*k, 1.181*k]
den = [ 1.0000, -2.6490, 1.6490]

sys = ct.tf(num, den, T)
print(sys)
# Out:
# <TransferFunction>: sys[0]
# Inputs (1): ['u[0]']
# Outputs (1): ['y[0]']
# dt = 0.1
#
#      0.149 z + 0.176
#   ---------------------
#   z^2 - 2.649 z + 1.649

# %% [markdown]
# Simulamos el sistema en BA

# %%
sal = ct.step_response(sys).plot()

# %% [markdown]
# Añadimos el controlador

# %%
kp = 11.644
num_cont = [1*kp, -0.736*kp]
den_cont = [1, 0.914]

sys_cont = ct.tf(num_cont, den_cont, T)
print(sys_cont)
# Out:
# <TransferFunction>: sys[3]
# Inputs (1): ['u[0]']
# Outputs (1): ['y[0]']
# dt = 0.1
#
#   11.64 z - 8.57
#   --------------
#     z + 0.914

# %% [markdown]
# Obtenemos la realimentación

# %%
sys_serie = ct.series(sys, sys_cont)
print(sys_serie)
#sal_serie = ct.step_response(sys_serie).plot()
sal_loop_cont = ct.feedback(sys_serie, 1, sign = -1)
print(sal_loop_cont)
# Out:
# <TransferFunction>: sys[4]
# Inputs (1): ['u[0]']
# Outputs (1): ['y[0]']
# dt = 0.1
#
#      1.735 z^2 + 0.7721 z - 1.508
#   ----------------------------------
#   z^3 - 1.735 z^2 - 0.7722 z + 1.507
# <TransferFunction>: sys[6]
# Inputs (1): ['u[0]']
# Outputs (1): ['y[0]']
# dt = 0.1
#
#          1.735 z^2 + 0.7721 z - 1.508
#   -------------------------------------------
#   z^3 - 4.4e-05 z^2 - 0.0001306 z - 0.0008655

# %% [markdown]
# Obtenemos la respuesta step

# %%
t, sal_loop = ct.step_response(sal_loop_cont)
salidaesp = [sal_loop(1), 5, 5, 5, 5, 5, 5, 5, 5, 5]
print(salidaesp)
l = len(t) 
for i in range(2,l):
    salidaesp.append(salidaesp, i, 5, 5, 5, 5, 5, 5, 5, 5, 5)
    if i==l:
        salidaesp.append(salidat(i))

plt.plot(t, sal_loop)
plt.plot(t, discreto, facecolor='C0', edgecolor='k')
plt.grid()
plt.xlabel("Seconds")
plt.ylabel("Amplitude")
plt.legend("Y")
# Out:
#   Cell In[7], line 4
#     for i in range(2:l:
#                     ^
# SyntaxError: invalid syntax
