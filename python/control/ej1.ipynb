# %% [markdown]
# Intro, etc

# %%
# Import the packages needed for the examples included in this notebook
import numpy as np
import matplotlib.pyplot as plt
import control as ct

# %%
# Definición de la fdt del sistema

a = [0.1, 0.5, -0.5, -0.1, 0.91, 1.2]
T = 0.5

# %%
num0 = [a[0]]
den0 = [1, a[0]]
sys0 = ct.tf(num0, den0, T)
print(sys0)
resp0 = ct.step_response(sys0).plot()
# Out:
# <TransferFunction>: sys[69]
# Inputs (1): ['u[0]']
# Outputs (1): ['y[0]']
# dt = 0.5
#
#     0.1
#   -------
#   z + 0.1

# %%
num1 = [a[1]]
den1 = [1, a[1]]

sys1 = ct.tf(num1, den1, T)
print(sys1)
resp1 = ct.step_response(sys1).plot()
# Out:
# <TransferFunction>: sys[72]
# Inputs (1): ['u[0]']
# Outputs (1): ['y[0]']
# dt = 0.5
#
#     0.5
#   -------
#   z + 0.5

# %%
num2 = [-a[2]]
den2 = [1, a[2]]
sys2 = ct.tf(num2, den2, T)
print(sys2)
resp2 = ct.step_response(sys2).plot()
# Out:
# <TransferFunction>: sys[75]
# Inputs (1): ['u[0]']
# Outputs (1): ['y[0]']
# dt = 0.5
#
#     0.5
#   -------
#   z - 0.5

# %%
num3 = [-a[3]]
den3 = [1, a[3]]
sys3 = ct.tf(num3, den3, T)
print(sys3)
resp3 = ct.step_response(sys3).plot()
# Out:
# <TransferFunction>: sys[78]
# Inputs (1): ['u[0]']
# Outputs (1): ['y[0]']
# dt = 0.5
#
#     0.1
#   -------
#   z - 0.1

# %%
num4 = [a[4]]
den4 = [1, a[4]]
sys4 = ct.tf(num4, den4, T)
print(sys4)
resp4 = ct.step_response(sys4).plot()
# Out:
# <TransferFunction>: sys[81]
# Inputs (1): ['u[0]']
# Outputs (1): ['y[0]']
# dt = 0.5
#
#     0.91
#   --------
#   z + 0.91

# %%
num5 = [a[5]]
den5 = [1, a[5]]
sys5 = ct.tf(num5, den5, T)
print(sys5)
resp5 = ct.step_response(sys5).plot()
# Out:
# <TransferFunction>: sys[84]
# Inputs (1): ['u[0]']
# Outputs (1): ['y[0]']
# dt = 0.5
#
#     1.2
#   -------
#   z + 1.2

# %%
# num6 = [a[6]]
# den6 = [a[6], a[6]]
# sys6 = ct.tf(num6, den6, T)
# print(sys6)
