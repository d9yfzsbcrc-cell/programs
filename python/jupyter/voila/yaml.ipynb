# %%
from IPython.display import Markdown
import json
import yaml

STR_JSON="""{"hey": {
  "1": "hi",
  "2": "yo",
  "a": {
    "b": [
      {"value": "3"},
      {"value": "5"},
      {"value": "5"}
    ]
  }
}}"""

parsed = json.loads(STR_JSON)            
s = yaml.dump(parsed, indent=2)
display(Markdown("\n```yaml\n" + s + "\n```"))
# Out:
# ```yaml
# hey:
#   '1': hi
#   '2': yo
#   a:
#     b:
#     - value: '3'
#     - value: '5'
#     - value: '5'
#
# ```
